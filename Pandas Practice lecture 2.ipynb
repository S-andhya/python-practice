# %% [markdown]
# ## Detecting null values
# Pandas data structures have two useful methods for detecting null data: isnull() and notnull(). Either one will return a Boolean mask over the data. For example:

# %%
import pandas as pd
import numpy as np

# %%
# one way to introduce null values inside pandas dataframe is np.nan
# nan is an alias for null values
# None is also another way to put null values inside pd dataframe
data =pd.Series([1,np.nan,'hello',None])
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %% [markdown]
# ## Operating on Null Values
# As we have seen, Pandas treats None and NaN as essentially interchangeable for indicating missing or null values. To facilitate this convention, there are several useful methods for detecting, removing, and replacing null values in Pandas data structures. They are:
#
# - isnull(): Generate a boolean mask indicating missing values
# - notnull(): Opposite of isnull()
# - dropna(): Return a filtered version of the data
# - fillna(): Return a copy of the data with missing values filled or imputed
# We will conclude this section with a brief exploration and demonstration of these routines.

# %%
# True if missing value
# False if value is present

data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data[data.isnull()]
# Out:
# 1     NaN
# 3    None
# dtype: object

# %%
# Filter out the null values
data.notnull()
# not null is baically opposite of is null
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %% [markdown]
# ## Dropping null values
#
# In addition to the masking used before, there are the convenience methods, dropna() (which removes NA values) and fillna() (which fills in NA values). For a Series, the result is straightforward:

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %% [markdown]
# For a DataFrame, there are more options. Consider the following DataFrame:

# %%
df = pd.DataFrame([[1,      np.nan, 2],
                   [2,      3,      5],
                   [np.nan, 4,      6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %% [markdown]
# We cannot drop single values from a DataFrame; we can only drop full rows or full columns. Depending on the application, you might want one or the other, so dropna() gives a number of options for a DataFrame.
#
# By default, dropna() will drop all rows in which any null value is present:

# %%
df.dropna()
# gives second column because first and last column contain Nan
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %% [markdown]
# Alternatively, you can drop NA values along a different axis; axis=1 drops all columns containing a null value:

# %%
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna(axis='columns')
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %% [markdown]
# But this drops some good data as well; you might rather be interested in dropping rows or columns with all NA values, or a majority of NA values. This can be specified through the how or thresh parameters, which allow fine control of the number of nulls to allow through.
#
# The default is how='any', such that any row or column (depending on the axis keyword) containing a null value will be dropped. You can also specify how='all', which will only drop rows/columns that are all null values:

# %%
df[3]=np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.dropna(axis='columns',how='all')
# will drop the column which has all the null values
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %% [markdown]
# For finer-grained control, the thresh parameter lets you specify a minimum number of non-null values for the row/column to be kept:

# %%
df
# you can see here as we dropped the 3rd column in above code but you still
# get the 3rd column, this is because we only dropped the column but 
# didn't save in the memory.
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.dropna(axis='rows',thresh=3)
# Out:
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %% [markdown]
# here the first and last row have been dropped because they contain only two non-null values

# %% [markdown]
# ## Filling null values

# %% [markdown]
# Sometimes rather than dropping NA values, you'd rather replace them with a valid value. This value might be a single number like zero, or it might be some sort of imputation or interpolation from the good values. You could do this in-place using the isnull() method as a mask, but because it is such a common operation Pandas provides the fillna() method, which returns a copy of the array with the null values replaced.
#
# Consider the following Series:

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=['a','b','c','d','e'])
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
# Or
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %% [markdown]
# We can fill NA entries with a single value, such as zero:

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %% [markdown]
# We can specify a forward-fill to propagate the previous value forward:

# %%
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
# forward-fill
# see above data dataframe 
# what 'ffill' does is it will propagate same value to NaN as previous
# for e.g. 1.0 is first value and then there was NaN value 
# So, after using ffill method second value becomes the same as previous
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# Or we can specify a back-fill to propagate the next values backward:

# %%
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %% [markdown]
# ## For multi dimensional pandas dataframe
# We can use same concept but with 'axis' parameter

# %%
df.fillna(method='ffill',axis='columns')
# Out:
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0

# %%
# Or 
df.fillna(method ='ffill',axis ='columns')
# Out:
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0

# %% [markdown]
# Notice that if a previous value is not available during a forward fill, the NA value remains.

# %% [markdown]
# ## Exploring data in pandas

# %%
data =pd.read_csv(r"C:\Users\visan\Downloads\titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Investigate the data types in the Dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#Get some summary statistics
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# ## Filtering data in Pandas

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# filter the values for the men
data[data.Sex=='male']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
#filter the ages for the men
data.Age[data.Sex=='male']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 12     20.0
# 13     39.0
# 16      2.0
# 17      NaN
# 20     35.0
# 21     34.0
# 23     28.0
# 26      NaN
# 27     19.0
# 29      NaN
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 36      NaN
# 37     21.0
# 42      NaN
# 45      NaN
# 46      NaN
# 48      NaN
# 50      7.0
# 51     21.0
# 54     65.0
# 55      NaN
# 57     28.5
#        ...
# 840    20.0
# 841    16.0
# 843    34.5
# 844    17.0
# 845    42.0
# 846     NaN
# 847    35.0
# 848    28.0
# 850     4.0
# 851    74.0
# 857    51.0
# 859     NaN
# 860    41.0
# 861    21.0
# 864    24.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 872    33.0
# 873    47.0
# 876    20.0
# 877    19.0
# 878     NaN
# 881    33.0
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 577, dtype: float64

# %% [markdown]
# ## Simple math operations in Pandas

# %% [markdown]
# #### Adding methods to filters
#
# A method is a function and is used frequently when analyzing data in Pandas. There are countless Pandas methods. We'll go over afew of the basic ones to show how you can use methods to quickly analyze your data

# %% [markdown]
# How many male and female were on the Titanic?

# %%
 
data[data.Sex=='male'].count()
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
data.Sex[data.Sex=='male'].count()
# Out:
# 577

# %% [markdown]
# What was the survival rate for adult men(age>=18)?

# %%
# survival rate = no. of survivors/total passengers(survivors and non-survivors)

data.Survived[(data.Sex=='male')&(data.Age>=18)].mean()
# Out:
# 0.17721518987341772

# %% [markdown]
# What was the survival rate for women and children?

# %%
data.Survived[(data.Sex =='female')|(data.Age<18)].mean()
# filters the values for female and both male and female children
# Out:
# 0.6881720430107527

# %% [markdown]
# Use groupby to compare the survival rates of men and women

# %%
# groupby methods take categorical columns and numerical column
# in this case categorical column is Sex and numerical is survived
data.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# categorical columns :sex, pclass
data.groupby(['Sex','Pclass'])['Survived'].mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64
